# %%
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('C:\\Users\\Ayushi\\Desktop\\machine learning practice\\creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.759072e-12 -8.251146e-13 -9.655448e-13  8.321385e-13
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.649983e-13  4.248434e-13 -3.054696e-13  8.777981e-14 -1.179757e-12
# ...

# %%
df.shape[1]
# Out:
# 31

# %%
count=pd.value_counts(df['Class'],sort=True)
count.plot(kind='bar',rot=0)
plt.xticks(range(2))
plt.xlabel('class')
plt.ylabel('frequency')
plt.title('transaction')
# Out:
# Text(0.5, 1.0, 'transaction')

# %%
normal=df[df['Class']==0]
fraud=df[df['Class']==1]

# %%
print(normal.shape,fraud.shape)
# Out:
# (284315, 31) (492, 31)

# %%
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
fig,(ax1,ax2)=plt.subplots(2,1,sharex=True)

plt.suptitle('transaction amount')
bins=50
ax1.hist(normal.Amount,bins=bins)
ax1.set_title('normal')
ax2.hist(fraud.Amount,bins=bins)
ax2.set_title('fraudelent')
plt.xlabel('amount')
plt.ylabel('no.of transaction')
plt.yscale('log')

# %%
fig,(ax1,ax2)=plt.subplots(2,1,sharex=True)

plt.suptitle('transaction time')
bins=50
ax1.scatter(normal.Time,normal.Amount)
ax1.set_title('normal')
ax2.scatter(fraud.Time,fraud.Amount)
ax2.set_title('fraudelent')
plt.xlabel('time')
plt.ylabel('amount')
plt.yscale('log')

# %%
outlier_fraction=len(fraud)/float(len(normal))

# %%
print(outlier_fraction)
print('fraud cases:{}'.format(len(fraud)))
print('normal cases:{}'.format(len(normal)))
# Out:
# 0.0017304750013189597
# fraud cases:492
# normal cases:284315

# %%
import seaborn as sns

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True,cmap='RdYlGn')

# %%
column=df.columns.tolist()

# %%
column=[c for c in column if c not in ['Class']]
target='Class'

# %%
import numpy as np

# %%
randoms=np.random.RandomState(50)

# %%
x=df[column]
y=df[target]

# %%
x.shape
# Out:
# (284807, 30)

# %%
y.shape
# Out:
# (284807,)

# %%
from sklearn.ensemble import IsolationForest
from sklearn.metrics import accuracy_score

# %%
isolation=IsolationForest( n_estimators=100,
    max_samples=len(x),
    contamination=outlier_fraction,
    random_state=randoms,
    verbose=0)

# %%
isolation.fit(x)
scores_prediction = isolation.decision_function(x)
y_pred = isolation.predict(x)
# Out:
# c:\users\ayushi\appdata\local\programs\python\python36\lib\site-packages\sklearn\ensemble\iforest.py:223: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# c:\users\ayushi\appdata\local\programs\python\python36\lib\site-packages\sklearn\ensemble\iforest.py:417: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)

# %%
y_pred[y_pred == 1] = 0
y_pred[y_pred == -1] = 1
n_errors = (y_pred != y).sum()

# %%
score=accuracy_score(y,y_pred)
score
# Out:
# 0.9976299739823811

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
print(n_errors)
# Out:
# 675

# %%
from sklearn.neighbors import LocalOutlierFactor

# %%
lof=LocalOutlierFactor(n_neighbors=20,
    algorithm='auto',
    leaf_size=30,
    metric='minkowski',
    p=2,
    metric_params=None,
    contamination=outlier_fraction)

# %%
y_pred=lof.fit_predict(x)
scores_prediction = lof.negative_outlier_factor_

# %%
y_pred[y_pred == 1] = 0
y_pred[y_pred == -1] = 1
n_errors = (y_pred != y).sum()
score=accuracy_score(y,y_pred)
score
# Out:
# 0.9967170750718908

# %%
n_errors
# Out:
# 935
